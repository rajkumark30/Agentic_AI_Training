# %% [markdown]
# <a href="https://colab.research.google.com/github/rajkumark30/Agentic_AI_Training/blob/main/lcel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### LCEL Deepdive

# %% [markdown]
# Install required dependencies for LangChain, Groq API integration, and vector storage.

# %%
# !pip install -qU langchain-groq langchain_community langchain_huggingface faiss-cpu

# %% [markdown]
# Set up environment variables and import necessary LangChain components for building chains with the Groq LLM.

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
#from dotenv import load_dotenv
#load_dotenv()
from google.colab import userdata
import os

os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %% [markdown]
# Create a simple LCEL chain: prompt → model → output parser. This demonstrates the pipe operator (|) chaining components together.

# %%
prompt = ChatPromptTemplate.from_template("Explain about {topic} in detail")
#model = ChatOpenAI()
# Initialize the Groq model
model = ChatGroq(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    temperature=0,
    max_retries=2,
)
output_parser = StrOutputParser()

chain = prompt | model | output_parser

chain.invoke({"topic": "ball"})
# Out:
# 'The ball! It\'s a simple yet fascinating object that has been a part of human culture and play for thousands of years. Let\'s dive into the world of balls and explore their history, types, physics, and more.\n\n**History of Balls**\n\nThe earliest known balls date back to around 2600 BCE, during the ancient civilizations of Egypt, Greece, and Rome. These early balls were made from materials like wood, clay, and animal skin. They were used for various purposes, including:\n\n1. Games and sports: Balls were used in ancient Olympic games, such as the Greek game of "phaininda" (a ball game played with a ball made of wood or leather).\n2. Rituals and ceremonies: Balls were used in ancient rituals, like the Egyptian game of "mehen" (a snake-like game played with a ball and stick).\n3. Toys: Balls were also used as toys for children, providing entertainment and promoting physical activity.\n\n**Types of Balls**\n\nOver time, balls have evolved and diversified into various types, each with its unique characteristics and uses. Here are some common types of balls:\n\n1. **Sports balls**:\n\t* Soccer balls (made of leather or synthetic materials)\n\t* Basketballs (made of leather or synthetic materials)\n\t* Tennis balls (made of rubber and felt)\n\t* Golf balls (made of surlyn or urethane)\n\t* Baseballs (made of cork and rubber)\n2. **Game balls**:\n\t* Pool balls (made of phenolic resin or polyester)\n\t* Bowling balls (made of urethane, reactive resin, or particle composite)\n\t* Billiards balls (made of ivory, phenolic resin, or polyester)\n3. **Toy balls**:\n\t* Bouncy balls (made of rubber or plastic)\n\t* Beach balls (made of plastic or vinyl)\n\t* Exercise balls (made of rubber or plastic, used for fitness and yoga)\n\t* Stress balls (made of foam, rubber, or plastic, used for stress relief)\n4. **Industrial balls**:\n\t* Ball bearings (used in machinery and mechanical systems)\n\t* Balls used in manufacturing processes (e.g., steel balls used in grinding and milling)\n\n**Physics of Balls**\n\nThe physics of balls is fascinating, involving concepts like motion, friction, and elasticity. Here are some interesting aspects:\n\n1. **Motion**: When a ball is thrown or hit, it follows a curved trajectory under the influence of gravity. The ball\'s motion can be described by the laws of motion, including velocity, acceleration, and momentum.\n2. **Friction**: Friction plays a crucial role in ball movement, as it affects the ball\'s interaction with surfaces. Different surfaces and materials can alter the ball\'s behavior, such as the spin, bounce, and roll.\n3. **Elasticity**: Balls can be elastic, meaning they can deform under impact and then return to their original shape. This property allows balls to bounce, which is essential for many games and sports.\n\n**Ball Materials**\n\nBalls are made from a wide range of materials, each with its advantages and disadvantages. Some common materials include:\n\n1. **Leather**: Leather is a popular material for sports balls, offering a natural, durable, and grippy surface.\n2. **Rubber**: Rubber is a versatile material used in balls, providing elasticity and resistance to abrasion.\n3. **Plastic**: Plastic is a common material for toy balls and industrial balls, offering a lightweight, durable, and affordable option.\n4. **Synthetic materials**: Synthetic materials, such as polyurethane and polyvinyl chloride (PVC), are used in various ball applications, including sports balls and industrial balls.\n\n**Ball Sizes and Shapes**\n\nBalls come in a wide range of sizes and shapes, depending on their intended use. Some balls are:\n\n1. **Spherical**: Most balls are spherical, providing a symmetrical and balanced shape.\n2. **Oval**: Some balls, like American footballs and rugby balls, have an oval shape.\n3. **Elliptical**: Some balls, like pool balls and bowling balls, have an elliptical shape.\n\n**Conclusion**\n\nThe ball is a simple yet fascinating object that has been a part of human culture ...

# %% [markdown]
# Inspect the prompt template output to see how variables are formatted before being passed to the model.

# %%
print(prompt.invoke({"topic": "ice cream"}))
# Out:
# messages=[HumanMessage(content='Explain about ice cream in detail', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# Invoke the model directly with chat messages to generate a response.

# %%
from langchain_core.messages.human import HumanMessage

messages = [HumanMessage(content='tell me a short joke about ice cream')]
model.invoke(messages)
# Out:
# AIMessage(content="Here's a short one:\n\nWhy did the ice cream go to therapy?\n\nBecause it had a meltdown!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 18, 'total_tokens': 41, 'completion_time': 0.052216781, 'completion_tokens_details': None, 'prompt_time': 9.2527e-05, 'prompt_tokens_details': None, 'queue_time': 0.236611266, 'total_time': 0.052309308}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_ba95244fa2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cd65d-c6f7-7282-b5c3-45580289990d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 23, 'total_tokens': 41})

# %% [markdown]
# ### What is this "|" in Python?

# %% [markdown]
# Implement a custom Runnable class to understand how the pipe operator (|) works. This creates a chain pattern where each component processes data sequentially.

# %%
from abc import ABC, abstractmethod

class CRunnable(ABC):
    def __init__(self):
        self.next = None

    @abstractmethod
    def process(self, data):
        """
        This method must be implemented by subclasses to define
        data processing behavior.
        """
        pass

    def invoke(self, data):
        processed_data = self.process(data)
        if self.next is not None:
            return self.next.invoke(processed_data)
        return processed_data

    def __or__(self, other):
        return CRunnableSequence(self, other)

class CRunnableSequence(CRunnable):
    def __init__(self, first, second):
        super().__init__()
        self.first = first
        self.second = second

    def process(self, data):
        return data

    def invoke(self, data):
        first_result = self.first.invoke(data)
        return self.second.invoke(first_result)

# %% [markdown]
# Define concrete Runnable implementations (AddTen, MultiplyByTwo, ConvertToString) to demonstrate data transformation through a chain.

# %%
class AddTen(CRunnable):
    def process(self, data):
        print("AddTen: ", data)
        return data + 10

class MultiplyByTwo(CRunnable):
    def process(self, data):
        print("Multiply by 2: ", data)
        return data * 2

class ConvertToString(CRunnable):
    def process(self, data):
        print("Convert to string: ", data)
        return f"Result: {data}"

# %% [markdown]
# Create a chain by composing three custom Runnables using the pipe operator.

# %%
a = AddTen()
b = MultiplyByTwo()
c = ConvertToString()

chain = a | b | c

# %% [markdown]
# Execute the chain and observe how data flows through each component sequentially.

# %%
result = chain.invoke(10)
print(result)
# Out:
# AddTen:  10
# Multiply by 2:  20
# Convert to string:  40
# Result: 40

# %% [markdown]
# ### Runnables from LangChain

# %% [markdown]
# Import LangChain's built-in Runnable types: RunnablePassthrough (passes data through unchanged), RunnableLambda (wraps functions), and RunnableParallel (processes multiple branches).

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda, RunnableParallel

# %% [markdown]
# Chain multiple RunnablePassthrough instances together, demonstrating that passthrough components return data unchanged.

# %%
chain = RunnablePassthrough() | RunnablePassthrough () | RunnablePassthrough ()
chain.invoke("hello")
# Out:
# 'hello'

# %% [markdown]
# Define a lambda function that converts input strings to uppercase.

# %%
def input_to_upper(input: str):
    output = input.upper()
    return output

# %% [markdown]
# Chain RunnablePassthrough with RunnableLambda to apply the uppercase transformation.

# %%
chain = RunnablePassthrough() | RunnableLambda(input_to_upper) | RunnablePassthrough()
chain.invoke("hello")
# Out:
# 'HELLO'

# %% [markdown]
# Create a RunnableParallel that simultaneously processes the same input through multiple branches, each stored as a key in the output dictionary.

# %%
chain = RunnableParallel({"x": RunnablePassthrough(), "y": RunnablePassthrough()})

# %% [markdown]
# Execute the parallel chain with a simple string input.

# %%
chain.invoke("hello")
# Out:
# {'x': 'hello', 'y': 'hello'}

# %% [markdown]
# Execute the parallel chain with a dictionary input to see how RunnablePassthrough handles structured data.

# %%
chain.invoke({"input": "hello", "input2": "goodbye"})
# Out:
# {'x': {'input': 'hello', 'input2': 'goodbye'},
#  'y': {'input': 'hello', 'input2': 'goodbye'}}

# %% [markdown]
# Create a RunnableParallel with a lambda function that extracts a specific key from the input dictionary.

# %%
chain = RunnableParallel({"x": RunnablePassthrough(), "y": lambda z: z["input2"]})

# %% [markdown]
# Execute the parallel chain, demonstrating selective extraction of input values.

# %%
chain.invoke({"input": "hello", "input2": "goodbye"})
# Out:
# {'x': {'input': 'hello', 'input2': 'goodbye'}, 'y': 'goodbye'}

# %% [markdown]
# ### Nested chains - now it gets more complicated!

# %% [markdown]
# Define a lambda function that extracts and transforms a specific key from the input dictionary.

# %%
def find_keys_to_uppercase(input: dict):
    output = input.get("input", "not found").upper()
    return output

# %% [markdown]
# Create a complex nested chain with RunnableParallel containing a sequential pipe (RunnablePassthrough | RunnableLambda) in one branch and a lambda in another.

# %%
chain = RunnableParallel({"x": RunnablePassthrough() | RunnableLambda(find_keys_to_uppercase), "y": lambda z: z["input2"]})

# %% [markdown]
# Execute the nested chain to show how complex transformations combine parallel and sequential processing.

# %%
chain.invoke({"input": "hello", "input2": "goodbye"})
# Out:
# {'x': 'HELLO', 'y': 'goodbye'}

# %% [markdown]
# Define helper functions for assignment and multiplication, then create a RunnableParallel as a base for further chaining.

# %%
chain = RunnableParallel({"x": RunnablePassthrough()})

def assign_func(input):
    return 100

def multiply(input):
    return input * 10

# %% [markdown]
# Execute the parallel chain with dictionary input.

# %%
chain.invoke({"input": "hello", "input2": "goodbye"})
# Out:
# {'x': {'input': 'hello', 'input2': 'goodbye'}}

# %% [markdown]
# Use the .assign() method to add new computed fields to the chain output while preserving existing data.

# %%
chain = RunnableParallel({"x": RunnablePassthrough()}).assign(extra=RunnableLambda(assign_func))

# %% [markdown]
# Execute the chain with assignment to display the combined result with both original and computed values.

# %%
result = chain.invoke({"input": "hello", "input2": "goodbye"})
print(result)
# Out:
# {'x': {'input': 'hello', 'input2': 'goodbye'}, 'extra': 100}

# %% [markdown]
# ### Combine multiple chains (incl. coercion)

# %% [markdown]
# Create extraction and transformation functions, then compose them into a new chain that extracts data and applies uppercase conversion.

# %%
def extractor(input: dict):
    return input.get("extra", "Key not found")

def cupper(upper: str):
    return str(upper).upper()

new_chain = RunnableLambda(extractor) | RunnableLambda(cupper)

# %% [markdown]
# Execute the extraction and transformation chain on a dictionary input.

# %%
new_chain.invoke({"extra": "test"})
# Out:
# 'TEST'

# %% [markdown]
# Combine the complex nested chain with the extraction chain to demonstrate chain coercion and composition.

# %%
final_chain = chain | new_chain
final_chain.invoke({"input": "hello", "input2": "goodbye"})
# Out:
# '100'

# %% [markdown]
# ### Real World Example

# %% [markdown]
# Build a Retrieval-Augmented Generation (RAG) chain: create embeddings, initialize a vector store with sample data, set up a retriever, and chain it with a prompt and LLM for context-aware question answering.

# %%
from langchain_community.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
#from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectorstore = FAISS.from_texts(
    ["cricket"], embedding=embeddings
)
retriever = vectorstore.as_retriever()
template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template=template)

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    RunnableParallel({"context": retriever | format_docs, "question": RunnablePassthrough()})
    | prompt
    | ChatGroq(model="llama-3.1-8b-instant", temperature=0, max_retries=2)
    | StrOutputParser()
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# Query the RAG chain with a question to generate an answer based on retrieved context.

# %%
rag_chain.invoke("What do cricketers eat?")
# Out:
# "Cricketers typically eat a balanced diet that includes a variety of foods to maintain their energy levels and support their physical performance. Some common foods that cricketers eat include:\n\n- Carbohydrates: Pasta, rice, bread, and cereals to provide energy for long periods of physical activity.\n- Protein: Chicken, fish, eggs, and lean meats to support muscle growth and repair.\n- Fresh fruits and vegetables: To provide essential vitamins, minerals, and antioxidants.\n- Nuts and seeds: To provide healthy fats and protein.\n- Sports drinks and hydration: To replenish lost fluids and electrolytes during and after matches.\n\nSome cricketers also follow specific diets, such as:\n\n- A high-carbohydrate diet before a match to provide energy.\n- A high-protein diet after a match to aid in muscle recovery.\n- A balanced diet that includes a mix of carbohydrates, protein, and healthy fats to support overall health and performance.\n\nIt's worth noting that individual dietary needs may vary depending on factors such as the player's position, level of play, and personal preferences."

# %% [markdown]
# Debug the RAG chain by inspecting the output of the RunnableParallel component to see the retrieved context and question.

# %%
RunnableParallel({"context": retriever | format_docs, "question": RunnablePassthrough()}).invoke("What do cricketers like to eat?")
# Out:
# {'context': 'cricket', 'question': 'What do cricketers like to eat?'}

# %% [markdown]
# Inspect the formatted prompt with injected context and question values.

# %%
prompt.invoke({"context": "Cats love thuna", "question": "What do cricketers like to eat?"})
# Out:
# ChatPromptValue(messages=[HumanMessage(content='Answer the question based only on the following context:\nCats love thuna\n\nQuestion: What do cricketers like to eat?\n', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# Execute the model on the formatted prompt to see the final LLM response before parsing.

# %%
model.invoke(prompt.invoke({"context": "Cats love thuna", "question": "What do cricketers like to eat?"}))
# Out:
# AIMessage(content='The context does not provide information about what cricketers like to eat. It only mentions that cats love tuna.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 35, 'total_tokens': 58, 'completion_time': 0.059448675, 'completion_tokens_details': None, 'prompt_time': 0.000858163, 'prompt_tokens_details': None, 'queue_time': 0.03428199, 'total_time': 0.060306838}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_5bd1e7ad73', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cd65d-d726-7b00-9680-68543863c910-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 23, 'total_tokens': 58})
